# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.patches import Rectangle
import matplotlib.colors as mcolors
import numpy as np

# %% [markdown]
# ## Importing files

# %%
# Reading the csv files
activity = pd.read_csv('daily_activity_dow.csv')
merged = pd.read_csv('dailyactivity_sleep_weight1.csv')
sleep_log = pd.read_csv('sleep_log_dow.csv')
weight_log = pd.read_csv('weight_log_dow.csv')

# %%
# sorting the dataframe by the day of the week
activity['DayofWeek'] = pd.Categorical(activity['DayofWeek'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
activity = activity.sort_values('DayofWeek')
activity.head()
# Out:
#              Id DayofWeek ActivityDate  TotalSteps  TotalDistance  \
# 845  8378563200    Monday       5/9/16        8382           6.65
# 112  1844505072    Monday       5/2/16           0           0.00
# 336  3977333714    Monday       5/2/16       16520          11.05
# 631  6290855005    Monday      4/18/16        6885           5.21
# 831  8378563200    Monday      4/25/16       12405           9.84
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 845             6.65                         2                1.27
# 112             0.00                         0                0.00
# 336            11.05                         0                1.54
# 631             5.21                         0                0.00
# 831             9.84                         2                5.05
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 845                      0.66                 4.72                     0.00
# ...

# %%
merged.head()
# Out:
#            Id  SedentaryMinutes  LightlyActiveMinutes  FairlyActiveMinutes  \
# 0  1503960366               728                   328                   13
# 1  1503960366               776                   217                   19
# 2  1503960366               726                   209                   34
# 3  1503960366               773                   221                   10
# 4  1503960366               539                   164                   20
#
#    VeryActiveMinutes  TotalMinutesAsleep
# 0                 25                 327
# 1                 21                 384
# 2                 29                 412
# 3                 36                 340
# 4                 38                 700

# %%
# sorting the dataframe by the day of the week
sleep_log['DayofWeek'] = pd.Categorical(sleep_log['DayofWeek'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
sleep_log = sleep_log.sort_values('DayofWeek')
sleep_log.head()
# Out:
#              Id DayofWeek     SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 290  7086361926    Monday  5/2/16 0:00                  1                 440
# 281  1644430081    Monday  5/2/16 0:00                  1                 796
# 282  2026352035    Monday  5/2/16 0:00                  1                 511
# 283  3977333714    Monday  5/2/16 0:00                  1                 230
# 284  4319703577    Monday  5/2/16 0:00                  1                 478
#
#      TotalTimeInBed  Unnamed: 6  Unnamed: 7
# 290             459         NaN         NaN
# 281             961         NaN         NaN
# 282             543         NaN         NaN
# 283             384         NaN         NaN
# 284             506         NaN         NaN

# %%
# sorting the dataframe by the day of the week
weight_log['DayofWeek'] = pd.Categorical(weight_log['DayofWeek'], ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
weight_log = weight_log.sort_values('DayofWeek')
weight_log.head()
# Out:
#             Id DayofWeek   Date 2           Date   WeightKg  WeightPounds  \
# 0   1503960366    Monday   5/2/16   5/2/16 23:59  52.599998    115.963146
# 26  6962181067    Monday  4/25/16  4/25/16 23:59  61.700001    136.025217
# 32  6962181067    Monday   5/2/16   5/2/16 23:59  61.500000    135.584291
# 39  6962181067    Monday   5/9/16   5/9/16 23:59  62.400002    137.568455
# 11  4558609924    Monday   5/9/16   5/9/16 23:59  69.099998    152.339420
#
#      Fat    BMI  IsManualReport         LogId
# 0   22.0  22.65            True  1.462230e+12
# 26   NaN  24.10            True  1.461630e+12
# 32   NaN  24.00            True  1.462230e+12
# 39   NaN  24.35            True  1.462840e+12
# 11   NaN  27.00            True  1.462840e+12

# %%
activity.head()
# Out:
#              Id DayofWeek ActivityDate  TotalSteps  TotalDistance  \
# 845  8378563200    Monday       5/9/16        8382           6.65
# 112  1844505072    Monday       5/2/16           0           0.00
# 336  3977333714    Monday       5/2/16       16520          11.05
# 631  6290855005    Monday      4/18/16        6885           5.21
# 831  8378563200    Monday      4/25/16       12405           9.84
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 845             6.65                         2                1.27
# 112             0.00                         0                0.00
# 336            11.05                         0                1.54
# 631             5.21                         0                0.00
# 831             9.84                         2                5.05
#
#      ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 845                      0.66                 4.72                     0.00
# ...

# %% [markdown]
# ## Frequency that Users Record Weight Data

# %%
plt.style.use("default")
plt.figure(figsize=(6,4)) # specify size of the chart
plt.hist(weight_log['DayofWeek'], bins = 7, 
         width = 0.6, color = "plum", edgecolor = "white")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Frequency")
plt.title("Number of Times Users Recorded Weight Data")
plt.grid(True)
plt.savefig('weightdata.png')
plt.show()

# %% [markdown]
# ## Frequency that Users Record Sleep Data

# %%
plt.style.use("default")
plt.figure(figsize=(6,4)) # specify size of the chart
plt.hist(sleep_log['DayofWeek'], bins = 7, 
         width = 0.6, color = "mediumpurple", edgecolor = "white")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Frequency")
plt.title("Number of Times Users Recorded Sleep Data")
plt.grid(True)
plt.savefig('sleepdata.png')
plt.show()

# %% [markdown]
# ## Average Steps Taken Per Day

# %%
activity_grouped = activity.groupby('DayofWeek').mean()[['TotalSteps', 'Calories']]
activity_grouped[['TotalSteps', 'Calories']] = grouped[['TotalSteps', 'Calories']].astype(int)
activity_grouped
# Out:
#            TotalSteps  Calories
# DayofWeek
# Monday           7780      2324
# Tuesday          8125      2356
# Wednesday        7559      2302
# Thursday         7405      2199
# Friday           7448      2331
# Saturday         8152      2354
# Sunday           6933      2263

# %%
plt.bar(activity_grouped.index, activity_grouped['TotalSteps'], width = 0.6, color = "darkseagreen", edgecolor = "white")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Number of Steps")
plt.title("Average Steps Taken Per Day")
plt.grid(True)
plt.savefig('avgsteps.png')
plt.show()

# %% [markdown]
# ## Average Calories Burned Per Day

# %%
plt.bar(activity_grouped.index, activity_grouped['Calories'], width = 0.6, color = "lightcoral", edgecolor = "white")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Number of Calories")
plt.title("Average Calories Burned Per Day")
plt.savefig('avgcalories.png')
plt.show()

# %% [markdown]
# ## Average Number of Sedentary Minutes Per Day

# %%
sedentary_min = activity.groupby('DayofWeek').mean()[['SedentaryMinutes']]
plt.bar(sedentary_min.index, sedentary_min['SedentaryMinutes'], width = 0.6, color = "lightskyblue", edgecolor = "white")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Number of Sedentary Minutes")
plt.title("Average Sedentary Minutes Per Day")
plt.savefig('avgsedentaryminutes.png')
plt.show()

# %% [markdown]
# ## Average Time To Fall Asleep Per Day

# %%
sleep_grouped = sleep_log.groupby('DayofWeek').mean()[['TotalMinutesAsleep', 'TotalTimeInBed']]
# subtracting the time in bed with minutes aslep to find how long it takes users to fall asleep every day of the week
sleep_grouped['TimetoSleep'] = sleep_grouped['TotalTimeInBed'] - sleep_grouped['TotalMinutesAsleep']
# converting values to integers
sleep_grouped[['TotalMinutesAsleep', 'TotalTimeInBed', 'TimetoSleep']] = sleep_grouped[['TotalMinutesAsleep', 'TotalTimeInBed', 'TimetoSleep']].astype(int)
sleep_grouped
# Out:
#            TotalMinutesAsleep  TotalTimeInBed  TimetoSleep
# DayofWeek
# Monday                    419             457           37
# Tuesday                   404             443           38
# Wednesday                 434             470           35
# Thursday                  401             434           33
# Friday                    405             445           39
# Saturday                  419             459           40
# Sunday                    452             503           50

# %%
plt.plot(sleep_grouped.index, sleep_grouped['TimetoSleep'], color = 'slateblue', marker="*")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Minutes to Sleep")
plt.title("Average Time it Takes to Fall Asleep Per Day")
plt.grid(True)
plt.savefig('timetosleep.png')
plt.show()

# %% [markdown]
# ## Average Minutes of Sleep Per Day

# %%
plt.bar(sleep_grouped.index, sleep_grouped['TotalMinutesAsleep'], width = 0.6, color = "orchid", edgecolor = "white")
# adding annotations and visuals
plt.xlabel("Day of the week")
plt.ylabel("Time Asleep (Minutes)")
plt.title("Average Total Minutes Asleep Per Day of Week")
plt.savefig('avgsleep.png')
plt.show()

# %% [markdown]
# ## Calories Burned vs Steps Taken in a Day

# %%
# plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(6,6)) # specify size of the chart
plt.scatter(activity['TotalSteps'], activity['Calories'], 
            alpha = 0.8, c = activity['Calories'], cmap = 'winter')
plt.colorbar(orientation = "vertical")
plt.xlabel("Steps taken")
plt.ylabel("Calories burned")
plt.title("Calories Burned vs Steps Taken in a Day")
plt.grid(True)
plt.savefig('CaloriesBurned.png')
plt.show()

# %%
# plotting scatter plot
plt.style.use("default")
plt.figure(figsize=(7,7)) # specify size of the chart
plt.scatter(activity['TotalSteps'], activity['Calories'], 
            alpha = 0.8, c = activity['Calories'], cmap = 'winter')

median_calories = 2303
median_steps = 7637
plt.colorbar(orientation = "vertical")
plt.axvline(median_steps, color = "orangered", label = "Median Steps")
plt.axhline(median_calories, color = "purple", label = "Median Calories Burned")
plt.xlabel("Steps Taken")
plt.ylabel("Calories Burned")
plt.title("Calories Burned vs Steps Taken in a Day")
plt.grid(True)
plt.legend()
plt.savefig('CaloriesBurnedMedian.png')
plt.show()

# %% [markdown]
# ## Activity Level and Total Sleeping Time

# %%
# sedentary minutes vs total minutes asleep
plt.scatter(merged['SedentaryMinutes'], merged['TotalMinutesAsleep'], 
            alpha = 0.8, c = merged['TotalMinutesAsleep'], cmap = 'winter')
plt.xlabel("Sedentary Minutes")
plt.ylabel("Total Minutes Asleep")
plt.title("Sedentary Minutes vs Total Minutes Asleep")

x = merged['SedentaryMinutes']
y = merged['TotalMinutesAsleep']
m, b = np.polyfit(x, y, 1)
#add linear regression line in black to scatterplot 
plt.plot(x, m*x+b, color = 'black')
plt.savefig('sedentaryandsleep.png')
plt.show()

# %%
#finding the correlation coeff
x = merged['SedentaryMinutes']
y = merged['TotalMinutesAsleep']
np.corrcoef(x, y)[0][1]
# Out:
# -0.6010731396971011

# %%
# lightly active minutes vs total minutes asleep
plt.scatter(merged['LightlyActiveMinutes'], merged['TotalMinutesAsleep'], 
            alpha = 0.8, c = merged['TotalMinutesAsleep'], cmap = 'winter')
plt.xlabel("Lightly Active Minutes")
plt.ylabel("Total Minutes Asleep")
plt.title("Lightly Active Minutes vs Total Minutes Asleep")

x = merged['LightlyActiveMinutes']
y = merged['TotalMinutesAsleep']
m, b = np.polyfit(x, y, 1)
#add linear regression line to scatterplot 
plt.plot(x, m*x+b, color = 'black')
plt.savefig('lightlyactiveandsleep.png')
plt.show()

# %%
#finding the correlation coeff
x = merged['LightlyActiveMinutes']
y = merged['TotalMinutesAsleep']
np.corrcoef(x, y)[0][1]
# Out:
# 0.027583356789564462

# %%
#fairly active minutes vs total minutes of sleep scatterplot
plt.scatter(merged['FairlyActiveMinutes'], merged['TotalMinutesAsleep'], 
            alpha = 0.8, c = merged['TotalMinutesAsleep'], cmap = 'winter')
plt.xlabel("Fairly Active Minutes")
plt.ylabel("Total Minutes Asleep")
plt.title("Fairly Active Minutes vs Total Minutes Asleep")

x = merged['FairlyActiveMinutes']
y = merged['TotalMinutesAsleep']
m, b = np.polyfit(x, y, 1)
#add linear regression line to scatterplot 
plt.plot(x, m*x+b, color = 'black')
plt.savefig('fairlyactiveandsleep.png')
plt.show()

# %%
#finding the correlation coeff
x = merged['FairlyActiveMinutes']
y = merged['TotalMinutesAsleep']
np.corrcoef(x, y)[0][1]
# Out:
# -0.2492079302480945

# %%
# very active minutes vs total minutes asleep
plt.scatter(merged['VeryActiveMinutes'], merged['TotalMinutesAsleep'], 
            alpha = 0.8, c = merged['TotalMinutesAsleep'], cmap = 'winter')
plt.xlabel("Very Active Minutes")
plt.ylabel("Total Minutes Asleep")
plt.title("Very Active Minutes vs Total Minutes Asleep")

x = merged['VeryActiveMinutes']
y = merged['TotalMinutesAsleep']
m, b = np.polyfit(x, y, 1)
#add linear regression line to scatterplot 
plt.plot(x, m*x+b, color = 'black')
plt.savefig('veryactiveandsleep.png')
plt.show()

# %%
#finding the correlation coeff
x = merged['VeryActiveMinutes']
y = merged['TotalMinutesAsleep']
np.corrcoef(x, y)[0][1]
# Out:
# -0.08812657953070487

# %% [markdown]
# ## Level of Activity Breakdown

# %%
# calculating total of individual minutes column
very_active_mins = activity["VeryActiveMinutes"].sum()
fairly_active_mins = activity["FairlyActiveMinutes"].sum()
lightly_active_mins = activity["LightlyActiveMinutes"].sum()
sedentary_mins = activity["SedentaryMinutes"].sum()

# plotting pie chart
slices = [very_active_mins, fairly_active_mins, lightly_active_mins, sedentary_mins]
labels = ["Very Active Minutes", "Fairly Active Minutes", "Lightly Active Minutes", "Sedentary Minutes"]

plt.style.use("default")
plt.pie(slices, labels = labels, 
        colors = ["cornflowerblue", "lightsalmon", "plum", "mediumturquoise"], wedgeprops = {"edgecolor": "white"}, autopct = "%1.1f%%")
plt.title("Percentage Breakdown of Activity in Minutes")
plt.tight_layout()
plt.savefig('PercentageBreakdown.png')
plt.show()

# %%
# To use different colors for creating graphs 
def plot_colortable(colors, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
# show the colors available
plot_colortable(mcolors.CSS4_COLORS)
plt.show()
